# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
import requests

url = "https://www.imdb.com/title/tt1187043/?ref_=nv_sr_srsg_0_tt_8_nm_0_q_3%2520id"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
print(response)
# Out:
# <Response [200]>

# %%
url_2 = "https://www.proitbridge.com/"

# %%
reponse = requests.get(url_2)

# %%
reponse
# Out:
# <Response [200]>

# %%
rating = soup.find("span", class_="sc-bde20123-1 cMEQkK")
rate = rating.text
print(rate)
# Out:
# 8.4

# %%
Director = '<a class="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link" role="button" tabindex="0" aria-disabled="false" href="/name/nm0386246/?ref_=tt_cl_dr_1">Rajkumar Hirani</a>'
soup = BeautifulSoup(Director, 'html.parser')
a_tag = soup.find('a')
name = a_tag.text.strip()
print("Director_name :",name)
# Out:
# Director_name : Rajkumar Hirani

# %%
Cast = '<a href="/name/nm0451148/?ref_=ttfc_fc_cl_t1"> Aamir Khan </a>'
soup = BeautifulSoup(Cast, 'html.parser')
Actor = soup.a.string.strip()
print(Actor)
# Out:
# Aamir Khan

# %%
Cast = '<a href="/name/nm0534856/?ref_=ttfc_fc_cl_t2"> Madhavan</a>'
soup = BeautifulSoup(Cast, 'html.parser')
name = soup.a.string.strip()
print(name)
# Out:
# Madhavan

# %%
Cast ='<a href="/name/nm0430817/?ref_=ttfc_fc_cl_t3"> Sharman Joshi</a>'
soup = BeautifulSoup(Cast, 'html.parser')
name = soup.a.string.strip()
print(name)
# Out:
# Sharman Joshi

# %%
Actor = ('<a href="/name/nm0451148/?ref_=ttfc_fc_cl_t1"> Aamir Khan </a>', '<a href="/name/nm0534856/?ref_=ttfc_fc_cl_t2"> Madhavan</a>','<a href="/name/nm0430817/?ref_=ttfc_fc_cl_t3"> Sharman Joshi</a>')
names = []

for item in Actor:
    soup = BeautifulSoup(item, 'html.parser')
    name = soup.a.string.strip()
    names.append(name)

print("Cast_name :",', '.join(names))
# Out:
# Cast_name : Aamir Khan, Madhavan, Sharman Joshi

# %%
import re

def extract_imdb_id(url):
    """
    Extracts the IMDb ID from a given IMDb URL.
    
    Args:
    - url (str): The IMDb URL
    
    Returns:
    - str: The extracted IMDb ID, or None if not found
    """
    pattern = r'tt(\d+)/'
    match = re.search(pattern, url)
    if match:
        return "tt" + match.group(1)
    else:
        return None

# %%
extract_imdb_id("https://www.imdb.com/title/tt1188996/?ref_=nv_sr_srsg_0_tt_4_nm_4_q_My%2520name%2520is%2520khan")
# Out:
# 'tt1188996'

# %%
pip install IMDbPY
# Out:
# ...
#    ---------------------------------------- 0.0/297.2 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/297.2 kB 1.4 MB/s eta 0:00:01
#    ------------- -------------------------- 102.4/297.2 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  297.0/297.2 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 297.2/297.2 kB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB 16.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.6/3.9 MB 7.0 MB/s eta 0:00:01
#    -------- ------------------------------- 0.8/3.9 MB 7.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.9 MB 6.5 MB/s eta 0:00:01
#    -------------- ------------------------- 1.4/3.9 MB 6.4 MB/s eta 0:00:01
#    --------------- ------------------------ 1.5/3.9 MB 6.1 MB/s eta 0:00:01
# ...

# %%
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie ID from IMDb using movie name
def get_movie_id(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the ID of the first movie in the search results
        movie_id = movies[0].movieID
        return movie_id
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None

# List of movie names
movie_names = [
'Suhaag',
'C Kkompany',
'Blood Money',
'Yamla Pagla Deewana Phir Se...',
'Saare Jahaan Se Mehnga...',
'Satya 2',
'Deewana Mujh Sa Nahin',
'The Gay Deceivers',



]

# Dictionary to store movie names and their corresponding IDs
movie_ids = {}

# Loop through the list of movie names and collect their IDs
for movie_name in movie_names:
    movie_id = get_movie_id(movie_name)
    if movie_id:
        movie_ids[movie_name] = movie_id

# Print the collected movie IDs
for movie_name, movie_id in movie_ids.items():
    print(movie_id)
# Out:
# 0111308
# 1170399
# 18413548
# 7609114
# 2857500
# 3059106
# 0101742
# 0064363

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [

'MSG the Warrior: Lion Heart',
'CC2C',
'Sachin - A Billion Dreams',
'Humshakals',
'Mission Mangal',
'Mohra',
'Awara Paagal Deewana',
'I Hate Luv Storys',
'Bhoothnath',
'Chup Chup Ke',
'Khoobsurat',
'Singh Is Bliing',
'Saawariya',
'Main Tera Hero',
"It's Entertainment",
'Socha Na Tha',
'Raju Ban Gaya Gentleman',
'Shubh Mangal Savdhan',







]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#    Movie ID                        Title  Year  \
# 0   6040012  MSG the Warrior: Lion Heart  2016
# 1   1091229                         CC2C  2009
# 2   4640206    Sachin - A Billion Dreams  2017
# 3   3036740                   Humshakals  2014
# 4   9248972               Mission Mangal  2019
# 5   0110546                        Mohra  1994
# 6   0319020         Awara Paagal Deewana  2002
# 7   1667838            I Hate Luv Storys  2010
# 8   0991346                   Bhoothnath  2008
# 9   0464160                 Chup Chup Ke  2006
# 10  3554418                   Khoobsurat  2014
# 11  3696192              Singh Is Bliing  2015
# 12  0758053                    Saawariya  2007
# 13  2762334               Main Tera Hero  2014
# 14  2978626           It's Entertainment  2014
# 15  0451919                 Socha Na Tha  2005
# 16  0173102      Raju Ban Gaya Gentleman  1992
# 17  6971752         Shubh Mangal Savdhan  2017
#
#                                        Genres  Rating  \
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Veer',
'Sarkar Raj',
'Rob Roy',
'Singham Returns',
'Agent Vinod',
"The Hitchhiker's Guide to the Galaxy",
'Dedh Ishqiya',
'Rocky Handsome',
'Shamitabh',
'Force',
'Duplicate',
'Befikre',
'Mughal-E-Azam',
'Page 3',
'Delhi-6',
'Raja Hindustani',
'Golmaal Returns',




]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                                 Title  Year  \
# 0    0420332                            Veer Zaara  2004
# 1    0490210                            Sarkar Raj  2008
# 2    0114287                               Rob Roy  1995
# 3    2309764                       Singham Returns  2014
# 4    1395025                           Agent Vinod  2012
# 5    0371724  The Hitchhiker's Guide to the Galaxy  2005
# 6    2675978                          Dedh Ishqiya  2014
# 7    3410408                        Rocky Handsome  2016
# 8    3836958                             Shamitabh  2015
# 9   20256448            Force of Nature: The Dry 2  2024
# 10   5639446                              Jonathan  2018
# 11   5108476                               Befikre  2016
# 12   0054098                         Mughal-E-Azam  1960
# 13   0443708                                Page 3  2005
# 14   1043451                               Delhi-6  2009
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    try:
        # Search for the movie
        movies = ia.search_movie(movie_name)
        
        # Check if any movie matches the search query
        if movies:
            # Get the first movie in the search results (most likely match)
            movie = movies[0]
            # Load full information about the movie
            ia.update(movie)
            
            # Extract desired information
            movie_id = movie.movieID
            title = movie.get('title')
            year = movie.get('year')
            genres = movie.get('genres')
            if genres:
                genres = ', '.join(genres)
            rating = movie.get('rating')
            top_cast = ', '.join([actor['name'] for actor in movie.get('cast', [])[:3]])  # Get top 3 cast members
            
            return movie_id, title, year, genres, rating, top_cast
        else:
            print(f"No movie found with the name '{movie_name}'")
            return None, None, None, None, None, None
    except Exception as e:
        print(f"An error occurred while fetching details for '{movie_name}': {e}")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Ram Gopal Varma Ki Aag',
'De Dana Dan',
'Dhadkan',
'O Saathiya',
'Phir Bhi Dil Hai Hindustani',
'Amar Akbar Anthony',
"Children's Party",
'Love Per Square Foot',
'Rehnaa Hai Terre Dil Mein',
'Salaam Namaste',
'Ishaqzaade',
'Once Upon a Time in Mumbaai',
'Baaghi',
'Ek Main Aur Ekk Tu',
'Hum Tumhare Hain Sanam',
'Manorama: Six Feet Under',
'Ek Hasina Thi',
'Hum Saath-Saath Hain',
"Viceroy's House",


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print("Movie Details:")
print(df)
# Out:
# Movie Details:
#     Movie ID                        Title  Year  \
# 0    0473310       Ram Gopal Varma Ki Aag  2007
# 1    1255951                  De Dana Dan  2009
# 2    0255111                      Dhadkan  2000
# 3   26243612                   O Saathiya  2023
# 4    0222270  Phir Bhi Dil Hai Hindustani  2000
# 5    0075669           Amar Akbar Anthony  1977
# 6    1841542             Children's Party  2011
# 7    7853242         Love Per Square Foot  2018
# 8    0299108    Rehnaa Hai Terre Dil Mein  2001
# 9    0456165               Salaam Namaste  2005
# 10   2308773                   Ishaqzaade  2012
# 11   1395054  Once Upon a Time in Mumbaai  2010
# 12   4864932                       Baaghi  2016
# 13   1703958           Ek Main Aur Ekk Tu  2012
# 14   0222024       Hum Tumhare Hain Sanam  2002
# 15   0920464     Manorama: Six Feet Under  2007
# 16   0352314                Ek Hasina Thi  2004
# 17   0216817         Hum Saath-Saath Hain  1999
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Mission Kashmir',
'Dishoom',
'Murder Mystery 2',
'Finding Fanny',
'Awarapan',
'Sui Dhaaga: Made in India',
'Ship of Theseus',
'No Smoking',
'Matru Ki Bijlee Ka Mandola',
'Hulchul',
'Bunty Aur Babli',
'Husband Material',
'Shuddh Desi Romance',
'Anjaana Anjaani',
'Deewana',
'Saajan',
'Dasvidaniya',
'Baar Baar Dekho',
'Lipstick Under My Burkha',


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                       Title  Year  \
# 0    0248185             Mission Kashmir  2000
# 1    3679060                     Dishoom  2016
# 2   15255288            Murder Mystery 2  2023
# 3    3142688               Finding Fanny  2014
# 4    1020937                    Awarapan  2007
# 5    7147540                  Sui Dhaaga  2018
# 6    1773764             Ship of Theseus  2012
# 7    0995740                  No Smoking  2007
# 8    2106537  Matru Ki Bijlee Ka Mandola  2013
# 9    0437238                     Hulchul  2004
# 10   0448206             Bunty Aur Babli  2005
# 11   5474036            Husband Material  2018
# 12   2988272         Shuddh Desi Romance  2013
# 13   1499201             Anjaana Anjaani  2010
# 14   0126871                     Deewana  1992
# 15   0102825                      Saajan  1991
# 16   1288638                 Dasvidaniya  2008
# 17   5197544             Baar Baar Dekho  2016
# 18   4807830    Lipstick Under My Burkha  2016
#
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [

'Half Girlfriend',
'Batla House',
'Mr. & Mrs. Khiladi',
'The Accidental Prime Minister',
'Anjaam',
'The Tashkent Files',
'Padosan',
'Satyameva Jayate',
'The Brawler',
'Grand Masti',
'Masti',
'Stanley Ka Dabba',
'Courage Under Fire',
'De De Pyaar De',
'Khiladiyon Ka Khiladi',
'Bluffmaster',
'Mumbai Meri Jaan',




]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                          Title  Year  \
# 0    5474042                Half Girlfriend  2017
# 1    8869978                    Batla House  2019
# 2    0162480             Mr. & Mrs. Khiladi  1997
# 3    6986710  The Accidental Prime Minister  2019
# 4   10717738                Anjaam Pathiraa  2020
# 5    8108268             The Tashkent Files  2019
# 6   30972533                        Padosan  2024
# 7    8202612               Satyameva Jayate  2018
# 8    5471472                    The Brawler  2019
# 9    2476154                    Grand Masti  2013
# 10   0406977                          Masti  2004
# 11   1907761               Stanley Ka Dabba  2011
# 12   0115956             Courage Under Fire  1996
# 13   8647400                 De De Pyaar De  2019
# 14   0246729          Khiladiyon Ka Khiladi  1996
# 15   0476527                    Bluffmaster  2005
# 16   1266583               Mumbai Meri Jaan  2008
#
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Agent Vinod',
"The Hitchhiker's Guide to the Galaxy",
'Dedh Ishqiya',
'Rocky Handsome',
'Shamitabh',
'Force',
'Duplicate',


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#    Movie ID                                 Title  Year  \
# 0   1395025                           Agent Vinod  2012
# 1   0371724  The Hitchhiker's Guide to the Galaxy  2005
# 2   2675978                          Dedh Ishqiya  2014
# 3   3410408                        Rocky Handsome  2016
# 4   3836958                             Shamitabh  2015
# 5  20256448            Force of Nature: The Dry 2  2024
# 6   5639446                              Jonathan  2018
#
#                              Genres  Rating  \
# 0       Action, Adventure, Thriller     5.2
# 1         Adventure, Comedy, Sci-Fi     6.7
# 2  Comedy, Drama, Romance, Thriller     7.0
# 3    Action, Crime, Drama, Thriller     6.8
# 4                             Drama     6.7
# 5                          Thriller     6.6
# 6  Drama, Mystery, Sci-Fi, Thriller     5.9
#
#                                            Top Cast
# 0        Kareena Kapoor, Saif Ali Khan, Ravi Kishan
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [

'Chamatkar',
'Dor',
'Kis Kisko Pyaar Karoon',
'Main Khiladi Tu Anari',
'Hunterrr',
'Jannat: In Search of Heaven...',
'Welcome Back',
'Bombay Velvet',
'Daawat-e-Ishq',
'All the Best: Fun Begins',
'Action Replayy',
'7 Khoon Maaf',
'Mausam',
'Salaam-E-Ishq',
'Hum Hain Rahi Pyar Ke',
'Bhavesh Joshi Superhero',
'Gangster',
'LSD: Love, Sex Aur Dhokha',
'Kismat Konnection',


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#    Movie ID                           Title  Year  \
# 0   0126234                       Chamatkar  1992
# 1   0824316                             Dor  2006
# 2   4302956          Kis Kisko Pyaar Karoon  2015
# 3   0110438           Main Khiladi Tu Anari  1994
# 4   4333674                        Hunterrr  2015
# 5   1216300  Jannat: In Search of Heaven...  2008
# 6   0072582            Welcome Back, Kotter  1975
# 7   2979920                   Bombay Velvet  2015
# 8   3398052                   Daawat-e-Ishq  2014
# 9   1433905        All the Best: Fun Begins  2009
# 10  1396208                  Action Replayy  2010
# 11  1629376                    7 Khoon Maaf  2011
# 12  0151511                      The Season  1975
# 13  0485272                   Salaam-e-Ishq  2007
# 14  0107166            Hum Hai Rahi Pyar Ke  1993
# 15  6129302         Bhavesh Joshi Superhero  2018
# 16  0765429               American Gangster  2007
# 17  1608777       LSD: Love, Sex Aur Dhokha  2010
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Malamaal Weekly',
'Azhar',
'Aligarh',
'Sangharsh',
'Total Dhamaal',
'Naam Shabana',
'Hamari Adhuri Kahani',
'Thirst',
'Any Body Can Dance 2',
'Thank You',
'Joker',
'Qarib Qarib Single',
'Ghayal Once Again',
'Chashme Baddoor',
'Ferrari Ki Sawaari',
'Judwaa',
'Phas Gaye Re Obama',
'Taal',
'Happy Bhaag Jayegi',
'Aarakshan',
'Satyagraha',
'Mujhse Dosti Karoge!',

]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#    Movie ID                  Title  Year  \
# 0   0476805        Malamaal Weekly  2006
# 1   4906984                  Azhar  2016
# 2   5121000                Aligarh  2015
# 3   0111068              Sangharsh  1999
# 4   7639372          Total Dhamaal  2019
# 5   6170954           Naam Shabana  2017
# 6   3483612   Hamari Adhuri Kahani  2015
# 7   0762073                 Thirst  2009
# 8   3679000   Any Body Can Dance 2  2015
# 9   0427944  Thank You for Smoking  2005
# 10  7286456                  Joker  2019
# 11  7399470     Qarib Qarib Single  2017
# 12  4683366      Ghayal Once Again  2016
# 13  2229848        Chashme Baddoor  2013
# 14  2122340     Ferrari Ki Sawaari  2012
# 15  0119428                 Judwaa  1997
# 16  1773015     Phas Gaye Re Obama  2010
# 17  0152836                   Taal  1999
# 18  5472758     Happy Bhaag Jayegi  2016
# 19  1848771              Aarakshan  2011
# 20  2275802             Satyagraha  2013
# 21  0272736   Mujhse Dosti Karoge!  2002
#
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Cheeni Kum',
'Tashan',
'Bombay Talkies',
'Housefull 4',
'Do Dooni Chaar',
'Dil',
'Nil Battey Sannata',
'One 2 Ka 4',
'PM Narendra Modi',
'Bhoothnath Returns',
'The 12th Man',
'Ghanchakkar',
'Kaal',
'Hazaaron Khwaishein Aisi',
'An Officer and a Gentleman',
'Shaandaar',
'Kurbaan',
'Angoor',
'Ek Chalis Ki Last Local',
'The Power of Shakti',
'Biwi No. 1',


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#    Movie ID                                      Title  Year  \
# 0   0976026                                 Cheeni Kum  2007
# 1   0995752                                     Tashan  2008
# 2   2797242                             Bombay Talkies  2013
# 3   7721946                                Housefull 4  2019
# 4   1714832                             Do Dooni Chaar  2010
# 5   0164538                                   Dil Se..  1998
# 6   5005684                         Nil Battey Sannata  2015
# 7   0227194                                 One 2 Ka 4  2001
# 8   9558612                           PM Narendra Modi  2019
# 9   3531852                         Bhoothnath Returns  2014
# 10  3300980                               The 12th Man  2017
# 11  2246724                                Ghanchakkar  2013
# 12  0415908                                       Kaal  2005
# 13  0411469                   Hazaaron Khwaishein Aisi  2003
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Parched',
'Mera Naam Joker',
'Akele Hum Akele Tum',
'Kaante',
'Mere Dad Ki Maruti',
'Dhol',
'Maine Pyaar Kyun Kiya',
'Blue',
'Gupt: The Hidden Truth',
'Batti Gul Meter Chalu',
'Yeh Dillagi',
'CityLights',
'Sabse Bada Khiladi',
'Deewane Huye Paagal',
'Fukrey Returns',
'Dream Girl',
'Bandit Queen',
'Tumhari Sulu',
'Fitoor',

]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#    Movie ID                   Title  Year  \
# 0   3043252                 Parched  2015
# 1   0066070         Mera Naam Joker  1970
# 2   0112313     Akele Hum Akele Tum  1995
# 3   0294662                  Kaante  2002
# 4   2323964      Mere Dad Ki Maruti  2013
# 5   0995035                    Dhol  2007
# 6   0451803   Maine Pyaar Kyun Kiya  2005
# 7   1595859             Blue Bloods  2010
# 8   0119239  Gupt: The Hidden Truth  1997
# 9   7720922   Batti Gul Meter Chalu  2018
# 10  0111793             Yeh Dillagi  1994
# 11  3709344              CityLights  2014
# 12  0114317      Sabse Bada Khiladi  1995
# 13  0444781     Deewane Huye Paagal  2005
# 14  6712014          Fukrey Returns  2017
# 15  9248940              Dream Girl  2019
# 16  0109206            Bandit Queen  1994
# 17  6791730            Tumhari Sulu  2017
# 18  4399594                  Fitoor  2016
#
#                                        Genres  Rating  \
# 0                                       Drama     7.5
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Nautanki Saala!',
'36 China Town',
'Baazaar',
'Apaharan',
'Ta Ra Rum Pum',
'Tere Naal Love Ho Gaya',
'Mela',
'Sarbjit',
'Har Dil Jo Pyar Karega...',
'Heroine',
'Pyaar Kiya To Darna Kya',
]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#    Movie ID                      Title  Year  \
# 0   2341766             Nautanki Saala  2013
# 1   0477252              36 China Town  2006
# 2   6514196                    Baazaar  2018
# 3   0451631                   Apaharan  2005
# 4   0833553              Ta Ra Rum Pum  2007
# 5   2130242     Tere Naal Love Ho Gaya  2012
# 6   0232079                       Mela  2000
# 7   5120640                    Sarbjit  2016
# 8   0250415  Har Dil Jo Pyar Karega...  2000
# 9   1949548                    Heroine  2012
# 10  0173080    Pyaar Kiya To Darna Kya  1998
#
#                                        Genres  Rating  \
# 0                      Comedy, Drama, Romance     5.8
# 1                   Comedy, Mystery, Thriller     5.7
# 2                      Crime, Drama, Thriller     6.5
# 3                        Action, Crime, Drama     7.4
# 4       Comedy, Drama, Family, Romance, Sport     5.7
# 5                      Comedy, Drama, Romance     5.9
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Laal Rang',
'Yamla Pagla Deewana',
'Break Ke Baad',
'Saheb Biwi Aur Gangster 3',
'Humko Deewana Kar Gaye',
'Mujhse Fraaandship Karoge',
'Yuvvraaj',
'Titli',
'Aurangzeb',
'Teri Meri Kahaani',
'Raja Natwarlal',
'Dum Maaro Dum',
'Ishq Vishk',
'Kill Dil',
'Raincoat',
'Ek Thi Daayan',
'Dil Hai Ki Manta Nahin',
'Players',


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                      Title  Year  \
# 0    5600714                  Laal Rang  2016
# 1    1773109            Crazy Mad Lover  2011
# 2    1578261              Break Ke Baad  2010
# 3    7695014  Saheb Biwi Aur Gangster 3  2018
# 4    0444840     Humko Deewana Kar Gaye  2006
# 5    2057441  Mujhse Fraaandship Karoge  2011
# 6    1105747                   Yuvvraaj  2008
# 7    3019620                      Titli  2014
# 8    2804026                  Aurangzeb  2013
# 9    2354407          Teri Meri Kahaani  2012
# 10   3483712             Raja Natwarlal  2014
# 11   1618430              Dum Maaro Dum  2011
# 12   0362771                 Ishq Vishk  2003
# 13   3380264                   Kill Dil  2014
# 14   0405266                   Raincoat  2004
# 15   2406676              Ek Thi Daayan  2013
# 16   0101733     Dil Hai Ke Manta Nahin  1991
# 17  14833464                    Players  2024
#
#                                         Genres  Rating  \
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Shaadi Ke Side Effects',
'Ghayal',
'Fiza',
'Saheb Biwi Aur Gangster Returns',
'Aiyaary',
'Dil Bole Hadippa',
'Bullett Raja',
'Kyaa Super Kool Hain Hum',
'Hello Brother',
'Bewakoofiyaan',
'Ram Jaane',
'Murder',
'Rangoon',
'Dil Toh Baccha Hai Ji',
'Zanjeer',
'The Caine Mutiny Court-Martial',
'OK Jaanu',
'God Tussi Great Ho',
'Kyon Ki...',
'Jattu Engineer',
'Judgementall Hai Kya',

]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                            Title  Year  \
# 0    3302962           Shaadi Ke Side Effects  2014
# 1    0099652                           Ghayal  1990
# 2    0248012                             Fiza  2000
# 3    2362778  Saheb Biwi Aur Gangster Returns  2013
# 4    6774212                          Aiyaary  2018
# 5    1202540                 Dil Bole Hadippa  2009
# 6    2551378                     Bullett Raja  2013
# 7    2027138         Kyaa Super Kool Hain Hum  2012
# 8    0233856                    Hello Brother  1999
# 9    3483646                    Bewakoofiyaan  2014
# 10   0114231             Ram Jaane: God Knows  1995
# 11  28642796                 A Killer Paradox  2024
# 12   4909752                          Rangoon  2017
# 13   1727496            Dil Toh Baccha Hai Ji  2011
# 14   2357489                          Zanjeer  2013
# 15  24249946   The Caine Mutiny Court-Martial  2023
# 16   5764024                         OK Jaanu  2017
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Meri Pyaari Bindu',
'Chhoti Si Baat',
'Gori Tere Pyaar Mein!',
'Hate Story',
'Shor in the City',
'Bawarchi',
'B.A. Pass',
'Ungli',
'Masoom',
'I Am Kalam',
'Awaara',
'Phillauri',
'A Flying Jatt',
'Filmistaan',
'Haraamkhor',
'Happy Ending',
'Pride and Honour',
'Ramaiya Vastavaiya',
'Rainbow',
'Mubarakan',
'Double Dhamaal',


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                  Title  Year  \
# 0    5472374      Meri Pyaari Bindu  2017
# 1    0072777         Chhoti Si Baat  1976
# 2    2275794  Gori Tere Pyaar Mein!  2013
# 3    2309987             Hate Story  2012
# 4    1916728       Shor in the City  2010
# 5    0068257               Bawarchi  1972
# 6    2408040              B.A. Pass  2012
# 7    2392447                  Ungli  2014
# 8    0085913                 Masoom  1983
# 9    1805263             I Am Kalam  2010
# 10   0043306                 Awaara  1951
# 11   5502766              Phillauri  2017
# 12   5235880          A Flying Jatt  2016
# 13   2417560             Filmistaan  2012
# 14   2361746             Haraamkhor  2015
# 15  21087084           Happy Ending  2023
# 16   0415003       Pride and Honour  2004
# 17   2357926     Ramaiya Vastavaiya  2013
# 18   0275148                Rainbow  1972
# 19   6272828              Mubarakan  2017
# 20   1728239         Double Dhamaal  2011
#
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Kaun?',
'Margarita with a Straw',
'Yaadein...',
'Jazbaa',
'Bhoot',
'Zinda',
'Lucky: No Time for Love',
'Aakrosh',
'Eklavya: The Royal Guard',
'1942: A Love Story',
'Raaz: The Mystery Continues',
'Pushpaka Vimana',
'Humsafar',
'Kyaa Kool Hai Hum',
'Action Jackson',
'Manto',
'Pataakha',
'Kabul Express',
'Welcome to Sajjanpur',
'Tum Bin II',
'Chakravyuh',


]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                        Title  Year  \
# 0    0195002                        Kaun?  1999
# 1    2929690       Margarita with a Straw  2014
# 2    0248617                   Yaadein...  2001
# 3    4323504                       Jazbaa  2015
# 4    0341266                        Bhoot  2003
# 5    0488906                        Zinda  2006
# 6    0449306      Lucky: No Time for Love  2005
# 7    1708453                      Aakrosh  2010
# 8    0459605     Eklavya: The Royal Guard  2007
# 9    0109010           1942: A Love Story  1994
# 10   1340838  Raaz: The Mystery Continues  2009
# 11   0251355              Pushpaka Vimana  1987
# 12  21245840                Mere Humsafar  2021
# 13   0456500            Kyaa Kool Hai Hum  2005
# 14   0094612               Action Jackson  1988
# 15   6923462                        Manto  2018
# 16   8396128                     Pataakha  2018
# 17   0770214                Kabul Express  2006
# ...

# %%
import pandas as pd
import imdb

# Create an instance of the IMDb class
ia = imdb.IMDb()

# Function to get movie details from IMDb using movie name
def get_movie_details(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    
    # Check if any movie matches the search query
    if movies:
        # Get the first movie in the search results (most likely match)
        movie = movies[0]
        # Load full information about the movie
        ia.update(movie)
        
        # Extract desired information
        movie_id = movie.movieID
        title = movie.get('title')
        year = movie.get('year')
        genres = ', '.join(movie.get('genres'))
        rating = movie.get('rating')
        top_cast = ', '.join([actor['name'] for actor in movie.get('cast')[:3]])  # Get top 3 cast members
        
        return movie_id, title, year, genres, rating, top_cast
    else:
        print(f"No movie found with the name '{movie_name}'")
        return None, None, None, None, None, None

# List of movie names
movie_names = [
'Dus',
'Jhoom Barabar Jhoom',
'Pyaar Ke Side Effects',
'Ghatak: Lethal',
'Baabul',
'Pyaar Impossible',
'Chalo Dilli',
'Shiva',
'Parinda',
'Satte Pe Satta',
'The Chess Players',
'F.A.L.T.U',
'Tevar',
'Jaani Dushman: Ek Anokhi Kahani',
'Ekk Deewana Tha',
'Darna Mana Hai',
'Humraaz',
'Total Chaos',
'Dulhan Hum Le Jayenge',
'Damini',

]

# List to store movie details
movie_data = []

# Loop through the list of movie names and collect their details
for movie_name in movie_names:
    movie_id, title, year, genres, rating, top_cast = get_movie_details(movie_name)
    if title:
        movie_data.append({
            'Movie ID': movie_id,
            'Title': title,
            'Year': year,
            'Genres': genres,
            'Rating': rating,
            'Top Cast': top_cast
        })

# Create DataFrame from movie data
df = pd.DataFrame(movie_data)

# Display DataFrame
print(df)
# Out:
#     Movie ID                            Title  Year  \
# 0    0415768                              Ten  2005
# 1    0833476              Jhoom Barabar Jhoom  2007
# 2    0480572            Pyaar Ke Side Effects  2006
# 3    0116407                   Ghatak: Lethal  1996
# 4    0419468                           Baabul  2006
# 5    1351224                 Pyaar Impossible  2010
# 6    1884268                      Chalo Dilli  2011
# 7   11317142                       Shiva Baby  2020
# 8   29932702               Parinda Paar Geyaa  2023
# 9    0084630                   Satte Pe Satta  1982
# 10   0076696                The Chess Players  1977
# 11  25503524                            Faltu  2022
# 12   3398048                            Tevar  2015
# 13   0326983  Jaani Dushman: Ek Anokhi Kahani  2002
# 14   2126282                  Ekk Deewana Tha  2012
# 15   0349333                   Darna Mana Hai  2003
# 16   0326576                          Humraaz  2002
# ...

# %%
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import json

def get_movie_info(url_link, movie_titles):
    headers = {'User-Agent': 'Mozilla/5.0'}
    try:
        url = requests.get(url_link, headers=headers)
        soup = BeautifulSoup(url.content, 'html.parser')

        script_tag_next = soup.find('script', {'type': 'application/json', 'id': '_NEXT_DATA_'})
        json_content = json.loads(script_tag_next.string)

        # Extracting id inside titleResults
        title_results = json_content['props']['pageProps']['titleResults']
        results_ids = [result['id'] for result in title_results['results']]

        # TO GO TO SPECIFIC MOVIE PAGE
        url_link = f"https://www.imdb.com/title/{results_ids[0]}"
        url = requests.get(url_link, headers=headers)
        soup = BeautifulSoup(url.content, 'html.parser')

        # Movie Name
        title_element = soup.title
        title_text = title_element.text.strip().split(' (')[0] if title_element else None
        movie_titles.append(title_text)

        # IMDB id
        parsed_url = urlparse(url_link)
        query_params = parsed_url.path
        cleaned_query = query_params.split('/')
        url_parts_filtered = [part for part in cleaned_query if part]
        imdb_id = url_parts_filtered[-1]

        # Year
        imdb_year = soup.find(class_='ipc-inline-list ipc-inline-list--show-dividers sc-d8941411-2 cdJsTz baseAlt')
        year = imdb_year.find('a').text if imdb_year else None

        # Rating
        imdb_rating_element = soup.find(class_='sc-bde20123-1 cMEQkK')
        imdb_rating = imdb_rating_element.text if imdb_rating_element else None

        # Genre
        movie_genre = []
        for div in soup.find_all('div', class_='ipc-chip-list__scroller'):
            for span in div.find_all('span', class_='ipc-chip__text'):
                genre = span.text
                movie_genre.append(genre)

        # Top cast
        movie_topcast = []
        cast = soup.find(class_='ipc-sub-grid ipc-sub-grid--page-span-2 ipc-sub-grid--wraps-at-above-l ipc-shoveler__grid')
        if cast:
            for span in cast.find_all('div', class_='sc-bfec09a1-5 hNfYaW'):
                movie_topcast.append(span.text)

        return {
            'Title': title_text,
            'IMDB id': imdb_id,
            'Year': year,
            'Rating': imdb_rating,
            'Genre': ', '.join(movie_genre),
            'Top_cast': ', '.join(movie_topcast[:3])  # Limiting to top 3 cast members
        }
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Load the existing data from movie_info.csv if it exists
if os.path.exists('movie_info.csv'):
    existing_df = pd.read_csv('movie_info.csv')
else:
    existing_df = pd.DataFrame()

# Load the entire testing.csv
testing_df = pd.read_csv('Movie_list.csv')

# Identify the rows that are new (not already in movie_info.csv)
new_rows = testing_df[~testing_df.index.isin(existing_df.index)]
print("new_rows-------->",new_rows)

# Iterate over each row and update information
movie_data = []

for index, row in new_rows.iterrows():
    title = row['Title']
    print("title-------->:",title)
    url_link = f"https://www.imdb.com/find/?q={title}&ref_=nv_sr_sm"
    movie_info = get_movie_info(url_link, [])
    if movie_info:
        movie_data.append(movie_info)

# Creating DataFrame from the list of dictionaries
df = pd.DataFrame(movie_data)

# Save to CSV file
df.to_csv('movie_info.csv', mode='a',  header=not os.path.exists('movie_info.csv'), index=False)
print("Uploaded SUCCESSFULLY")
